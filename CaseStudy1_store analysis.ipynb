# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv(r"C:\Users\shree\Downloads\retail_sales_case_study.csv")
sales.head()
# Out:
#   Invoice_ID        Date Store_ID Region Customer_ID Customer_Type  \
# 0    INV1000  2023-04-13    ST002  South     CUST113           New
# 1    INV1001  2023-12-15    ST017  South     CUST762           New
# 2    INV1002  2023-09-28    ST020  North     CUST493           New
# 3    INV1003  2023-04-17    ST012  North     CUST909           New
# 4    INV1004  2023-03-13    ST018   East     CUST595     Returning
#
#   Product_Category Product_ID  Quantity  Unit_Price Payment_Method  \
# 0           Tablet       P731         1    39793.30           Card
# 1           Tablet       P985         2    27893.09            EMI
# 2           Tablet       P278         5    31032.11            EMI
# 3           Laptop       P296         2    12081.21           Card
# 4           Laptop       P152         1    42499.02            UPI
#
#    Total_Price
# 0     39793.30
# 1     55786.18
# 2    155160.55
# 3     24162.42
# 4     42499.02

# %% [markdown]
# ### Data Cleaning

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Invoice_ID        500 non-null    object
#  1   Date              500 non-null    object
#  2   Store_ID          500 non-null    object
#  3   Region            500 non-null    object
#  4   Customer_ID       500 non-null    object
#  5   Customer_Type     500 non-null    object
#  6   Product_Category  500 non-null    object
#  7   Product_ID        500 non-null    object
#  8   Quantity          500 non-null    int64
#  9   Unit_Price        500 non-null    float64
#  10  Payment_Method    500 non-null    object
#  11  Total_Price       500 non-null    float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 47.0+ KB

# %%
sales['Date'] = pd.to_datetime(sales['Date'])
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Invoice_ID        500 non-null    object
#  1   Date              500 non-null    datetime64[ns]
#  2   Store_ID          500 non-null    object
#  3   Region            500 non-null    object
#  4   Customer_ID       500 non-null    object
#  5   Customer_Type     500 non-null    object
#  6   Product_Category  500 non-null    object
#  7   Product_ID        500 non-null    object
#  8   Quantity          500 non-null    int64
#  9   Unit_Price        500 non-null    float64
#  10  Payment_Method    500 non-null    object
#  11  Total_Price       500 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 47.0+ KB

# %%
sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Basic Analysis
#
# Total revenue generated.
#
# Total units sold.
#
# Average transaction amount

# %%
total_revenue = sales['Total_Price'].sum()
total_revenue
# Out:
# 39362185.89

# %%
total_quantity = sales['Quantity'].sum()
total_quantity
# Out:
# 1534

# %%
average_transaction = sales['Total_Price'].mean()
average_transaction
# Out:
# 78724.37178

# %% [markdown]
# ### Sales Trends
#
# Plot monthly sales trend.
#
# Identify the month with highest and lowest sales.
