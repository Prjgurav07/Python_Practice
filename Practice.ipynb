# %%
# A student will not be alllowed to sit in exam if his/her attendence is less thsn 75%.

# %%
Total_class=int(input("Enter total number of classes held:"))
class_attend=int(input("Enter number of classes attended:"))
attendence=(class_attend/Total_class)*100
if attendence>=75.0:
    print("Allowed to sit in exam",attendence)
else:
    print("Not allowed to sit in exam",attendence)
# Out:
# Enter total number of classes held: 200
# Enter number of classes attended: 150
# Allowed to sit in exam 75.0

# %%
age=int(input("Enter your age:"))
gender=input("Enter your gender(M or F):")
material_status=input("Enter your material status(Y or N):")
if gender.upper()=="F":
    print("Employee will work only in urban areas.")
elif gender.upper()=="M" and age>=20 and age<40:
    print("Employee may work anywhere.")
elif gender.upper()=="M" and age>=40 and age<60:
    print("Employee will work in urban area only.")
else:
    print("Error")
# Out:
# Enter your age: 56
# Enter your gender(M or F): M
# Enter your material status(Y or N): Y
# Employee will work in urban area only.

# %%
salary=int(input("Enter your salary:"))
Time_period=int(input("Enter your year of services:"))
if Time_period >10:
    total_salary=salary+(salary*10)/100
    print(total_salary)
elif Time_period>=6 and Time_period>=10:
    total_salary=salary+(salary*8)/100
    print(total_salary)
elif Time_period<6:
    total_salary=salary+(salary*5)/100
    print(total_salary)
# Out:
# Enter your salary: 80000
# Enter your year of services: 10
# 86400.0

# %%
units=int(input("Enter number of units"))
if units<=100:
    print("No charges")
elif units>100 and units<=200:
    print("You have to pay:",(units-100)*5)
elif units>200:
    print("You have to pay:",(units-100)*10+500)
# Out:
# Enter number of units 213
# You have to pay: 1630

# %%
p=int(input("Enter amount:"))
r=int(input("Enter rate of interest:"))
t=int(input)
